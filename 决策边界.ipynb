# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.arange(1, 2, 0.2)
# Out:
# array([1. , 1.2, 1.4, 1.6, 1.8])

# %%
np.arange(2, 3, 0.2)
# Out:
# array([2. , 2.2, 2.4, 2.6, 2.8])

# %%
x, y = np.meshgrid(np.arange(1, 2, 0.2), np.arange(2, 3, 0.2))

# %%
x
# Out:
# array([[1. , 1.2, 1.4, 1.6, 1.8],
#        [1. , 1.2, 1.4, 1.6, 1.8],
#        [1. , 1.2, 1.4, 1.6, 1.8],
#        [1. , 1.2, 1.4, 1.6, 1.8],
#        [1. , 1.2, 1.4, 1.6, 1.8]])

# %%
y
# Out:
# array([[2. , 2. , 2. , 2. , 2. ],
#        [2.2, 2.2, 2.2, 2.2, 2.2],
#        [2.4, 2.4, 2.4, 2.4, 2.4],
#        [2.6, 2.6, 2.6, 2.6, 2.6],
#        [2.8, 2.8, 2.8, 2.8, 2.8]])

# %%
plt.scatter(x, y)
plt.show()

# %%
X = np.concatenate([x.reshape(-1, 1), y.reshape(-1, 1)], axis=1)
X
# Out:
# array([[1. , 2. ],
#        [1.2, 2. ],
#        [1.4, 2. ],
#        [1.6, 2. ],
#        [1.8, 2. ],
#        [1. , 2.2],
#        [1.2, 2.2],
#        [1.4, 2.2],
#        [1.6, 2.2],
#        [1.8, 2.2],
#        [1. , 2.4],
#        [1.2, 2.4],
#        [1.4, 2.4],
#        [1.6, 2.4],
#        [1.8, 2.4],
#        [1. , 2.6],
#        [1.2, 2.6],
#        [1.4, 2.6],
#        [1.6, 2.6],
#        [1.8, 2.6],
#        [1. , 2.8],
#        [1.2, 2.8],
#        [1.4, 2.8],
#        [1.6, 2.8],
#        [1.8, 2.8]])

# %%
def height(x):
    # 1 2
    return np.abs(x[0] -1 ) * (x[1] - 2)

# %%
z = np.array([height(x) for x in X])

# %%
z
# Out:
# array([0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.04, 0.08, 0.12, 0.16, 0.  ,
#        0.08, 0.16, 0.24, 0.32, 0.  , 0.12, 0.24, 0.36, 0.48, 0.  , 0.16,
#        0.32, 0.48, 0.64])

# %%
z = z.reshape(x.shape)

# %%
z
# Out:
# array([[0.  , 0.  , 0.  , 0.  , 0.  ],
#        [0.  , 0.04, 0.08, 0.12, 0.16],
#        [0.  , 0.08, 0.16, 0.24, 0.32],
#        [0.  , 0.12, 0.24, 0.36, 0.48],
#        [0.  , 0.16, 0.32, 0.48, 0.64]])

# %%
# 绘制等高线
plt.contour(x, y, z)
plt.show()

# %%
plt.contourf(x, y, z, 20, cmap=plt.cm.hot)
plt.show()

# %%
X = np.loadtxt('x.txt')
X = X[:, 2:]
y = np.loadtxt('y.txt')

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
def plot_decision_boundary(X, y, predict_func, step=0.1):
    x_min = X[:, 0].min() - 0.5
    x_max = X[:, 0].max() + 0.5
    y_min = X[:, 1].min() - 0.5
    y_max = X[:, 1].max() + 0.5
    
    x_mesh, y_mesh = np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))
    labels = predict_func(np.concatenate([x_mesh.reshape(-1, 1), y_mesh.reshape(-1, 1)], axis=1))
    z = labels.reshape(x_mesh.shape)
    
    plt.contourf(x_mesh, y_mesh, z, cmap=plt.cm.Spectral)
    
    plt.scatter(X[:, 0], X[:, 1], c=y)
    plt.show()

# %%
def plot_decision_boundary(X ,y,predict_func, step=0.1):
    x_min=X[:,0].min() - 0.5
    x_max=X[:,0].min() + 0.5
    y_min=X[:,1].min() - 0.5
    y_max=X[:,1].min() + 0.5
    
    x_mesh,y_mesh = np.meshgrid(np.arange(x_min,x_max,step), np.arange(y_min,y_max,step))
    
    labels = predict_func(np.concatenate([x_mesh.reshape(-1, 1),y_mesh.reshape(-1,1)],axis=1))
    z = labels.reshape(x_mesh.shape)
    
    plt.contourf(x_mesh,y_mesh,z,cmap=plt.cm.Sepctral)

# %%
plt.scatter?

# %%
from ML.knn import KNeighborsClassifier

# %%
knn_clf = KNeighborsClassifier()
knn_clf.fit(X, y)

# %%
plot_decision_boundary(X, y, lambda x: knn_clf.predict(x))

# %%
from ML.tree import DecisionTreeClassfier

# %%
dt_clf = DecisionTreeClassfier()
dt_clf.fit(X, y)

# %%
# %%time
# plot_decision_boundary(X, y, lambda x: knn_clf.predict(x), step=0.01)

# %%
# %%time
plot_decision_boundary(X, y, lambda x: dt_clf.predict(x), step=0.01)
# Out:
# Wall time: 513 ms

# %%
scatter.__doc__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-36ad701233da> in <module>
# ----> 1 scatter.__doc__
#
# NameError: name 'scatter' is not defined
